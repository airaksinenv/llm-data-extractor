# %% [markdown]
# # Gpt4.0 -mini
#
# Tässä notebookissa käytetään `gpt4.o mini` mallia vapaan tekstin kenttien parsimiseen. Kun olet luonut virtuaaliympäristön niin valitse se ennen koodin ajamista notebookin oikeasta yläreunasta `Select Kernel` -kohdasta

# %%
# Vaadittavat importtaukset
import pandas as pd
from utils import extractValuesFromText

# %%
# Tässä määritellään polut prompteihin ja minne tulokset halutaan sekä kasvin nimi tyhjien rivien tietojen täyttöä varten
path_to_prompt = "data/prompts/RNprompt.md"
output_path = "data/results/gpt4mini_test_results.txt"
plant_name = "Ruokonata"

# Lue data
df = pd.read_excel('data/resources/korjuuaika-taustatiedot-2020-2024-combined.xlsx')
#df = pd.read_excel('data/resources/korjuuaika-koordinaateilla-updated-0.03.xlsx')

# Sample testikäyttöön
df = df.sample(500)

# Kutsu funktiota
extractValuesFromText(df, path_to_prompt, output_path, plant_name)
# Out:
# Käydään rivejä läpi: 100%|██████████| 500/500 [00:42<00:00, 11.83it/s]
# Tiedosto käyty läpi ja tulokset löytyvät kohteesta: data/results/gpt4mini_test_results.txt
