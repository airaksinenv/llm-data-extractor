# %%
# Vaadittavat importtaukset
import pandas as pd
from utils import extractValuesFromTextLlama

# %%
# Tässä määritellään polut prompteihin ja minne tulokset halutaan sekä kasvin nimi tyhjien rivien tietojen täyttöä varten
path_to_prompt = "data/prompts/RNprompt.md"
output_path = "data/results/llama_test_results.txt"

# Lue data
#df = pd.read_excel('data/resources/Korjuuaikanäytteiden_lisätiedot_16082024.xlsx')
df = pd.read_excel('data/resources/korjuuaika-taustatiedot-2020-2024-combined.xlsx')

# Sample testikäyttöön
df = df.sample(500)

# Kutsu funktiota
extractValuesFromTextLlama(df, path_to_prompt, output_path)
# Out:
# Käydään rivejä läpi: 100%|██████████| 500/500 [18:37<00:00,  2.24s/it]
# Tiedosto käyty läpi ja tulokset löytyvät kohteesta: data/results/llama_test_results.txt
